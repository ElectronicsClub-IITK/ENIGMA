# %% [markdown]
# # Welcome to the Enigma GUI Interface Project! 🧩🔐
#
# In this project, we'll use Python and a library called PySimpleGUI to build a Graphical User Interface (GUI) that connects to an Enigma-like encryption machine (connected via a microcontroller).
#
# We'll learn:
# - How GUI layouts work 🧱
# - How to send messages to a serial device 💬
# - How to interact with buttons, sliders, listboxes, and inputs 👆
#
# References :
#  - [PySimpleGUI Doc](https://docs.pysimplegui.com/en/latest/)
#  - [Tutoral link](https://www.tutorialspoint.com/pysimplegui/)

# %%
# If you're using Google Colab or a local setup, run this line to install PySimpleGUI
# !pip install PySimpleGUI
# !pip install serial
# Out:
# Requirement already satisfied: PySimpleGUI in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (5.0.10)
# Requirement already satisfied: rsa in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (from PySimpleGUI) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (from rsa->PySimpleGUI) (0.6.1)
# Requirement already satisfied: serial in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (0.0.97)
# Requirement already satisfied: future>=0.17.1 in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (from serial) (1.0.0)
# Requirement already satisfied: pyyaml>=3.13 in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (from serial) (6.0.2)
# Requirement already satisfied: iso8601>=0.1.12 in c:\users\sahil\appdata\local\programs\python\python313\lib\site-packages (from serial) (2.1.0)

# %% [markdown]
# Install Required Libraries

# %%
import PySimpleGUI as sg
import serial
import time


print(serial.__file__)          # Confirm correct path
print(dir(serial))              # Show all attributes in the module
# Out:
# c:\Users\sahil\AppData\Local\Programs\Python\Python313\Lib\site-packages\serial\__init__.py
# ['CR', 'EIGHTBITS', 'FIVEBITS', 'LF', 'PARITY_EVEN', 'PARITY_MARK', 'PARITY_NAMES', 'PARITY_NONE', 'PARITY_ODD', 'PARITY_SPACE', 'PortNotOpenError', 'SEVENBITS', 'SIXBITS', 'STOPBITS_ONE', 'STOPBITS_ONE_POINT_FIVE', 'STOPBITS_TWO', 'Serial', 'SerialBase', 'SerialException', 'SerialTimeoutException', 'Timeout', 'VERSION', 'XOFF', 'XON', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'absolute_import', 'basestring', 'importlib', 'io', 'iterbytes', 'os', 'protocol_handler_packages', 'serial_for_url', 'serialutil', 'serialwin32', 'sys', 'time', 'to_bytes', 'unicode', 'win32']

# %%
# Create a serial connection to the microcontroller (replace 'COM4' with your correct port)
ser = serial.Serial('COM6', 115200, timeout=0.001)
#Task: What does 115200 mean in the above line? Why do we need timeout=0.001? Try changing it and observe!

# %% [markdown]
# ### Task (for the code below):
#
# - Add three more text input sections for rotor1, rotor2, and rotor3.
#
# - Add a listbox to choose letters for the rotors from A

# %%
font_spec = 'Courier 24 bold'
heading_color = '#2FB8AD'
alphabet_list = list("ABCDEFGHIJKLMNOPQRSTUVWXYZ")

# This defines how the GUI looks
layout = [
    [sg.Text('Please Input Characters', background_color=heading_color)],
    [sg.InputText('', key='pic_input'), sg.Button('Send', key='pic_send')],
    ...
]

# %% [markdown]
# ### Apply Custom Theme to GUI
# Task: Try changing colors! Make your GUI colorful!

# %%
sg.SetOptions(
    background_color='#9FB8AD',
    text_element_background_color='#9FB8AD',
    element_background_color='#475841',
    button_color=('white', '#475841'),
)

# %%
##Create and show the window
window = sg.Window('ECE4760 Interface', layout, location=(0, 0), finalize=True)

# %%
while True:
    event, values = window.read(timeout=20)
    
    if event == sg.WIN_CLOSED or event == 'Exit':
        break

    # Send typed message to PIC
    if event == 'pic_send':
        message = values['pic_input']
        ser.write((message + '\r').encode())

# %% [markdown]
# **Task**: Add event handling for `rotor1_send`, `rotor2_send`, and `rotor3_send`. Also, read serial data and show it in the `console`.

# %%
# Reset only if checkbox is selected and RESET button clicked
if event == 'rtg' and values['r_en']:
    ser.send_break()  # sends a reset signal to the PIC

# %% [markdown]
# **Task**: Add a checkbox called 'Enable Reset' and a button called 'RESET PIC'.

# %%
# Close window after loop ends
window.close()
